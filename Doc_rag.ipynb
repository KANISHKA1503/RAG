# %%
# !pip install langchain pypdf

# %%
# !pip install langchain-text-splitters langchain-community

# %%
from langchain_community.document_loaders import PyPDFLoader
pdf_path='/content/sample_data/about cse department.pdf'
loader=PyPDFLoader(pdf_path)
documents=loader.load()
documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-07T18:03:25+05:30', 'author': 'Kanishka Sennimalai', 'moddate': '2025-12-07T18:03:25+05:30', 'source': '/content/sample_data/about cse department.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content='The scope of learning for you in our CSE program will include Artificial Intelligence, \nMachine Learning, Agile Software Development, Cybersecurity, AR/VR , OOPS Concepts, \nComputer Architecture, Computer Networks, Database Management System, Software \ntechnologies including C, Python for Data Science and Java Full Stack.The department \nhaving highly experience and capable faculty who are trained by the Industry, state of the \nart infrastructure and Industry Powered Nextgen Laboratories in AI-ML, Cloud \nTechnologies,Data Science and Design Thinking. \nCAREER PROGRESSION \n \n The scope of career progression, studying CSE, is abundant and unlimited with 
# ...

# %%
full_text = " ".join([doc.page_content for doc in documents])

# %%
from langchain_text_splitters import  RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

splitter= RecursiveCharacterTextSplitter(
    chunk_size=30, #individual chunk can have 30 words
    chunk_overlap=5  #if need more info
    )

chunks=splitter.split_text(full_text)
len(chunks)
print(chunks)
# Out:
# ['The scope of learning for you', 'you in our CSE program will', 'will include Artificial', 'Intelligence,', 'Machine Learning, Agile', 'Software Development,', 'Cybersecurity, AR/VR , OOPS', 'OOPS Concepts,', 'Computer Architecture,', 'Computer Networks, Database', 'Management System, Software', 'technologies including C,', 'C, Python for Data Science', 'and Java Full Stack.The', 'department', 'having highly experience and', 'and capable faculty who are', 'are trained by the Industry,', 'state of the', 'art infrastructure and', 'and Industry Powered Nextgen', 'Laboratories in AI-ML, Cloud', 'Technologies,Data Science and', 'and Design Thinking.', 'CAREER PROGRESSION', 'The scope of career', 'progression, studying CSE, is', 'is abundant and unlimited', 'with leading', 'multinational IT companies', 'recruiting fresh CSE', 'CSE graduates in large', 'numbers, or becoming', 'an entrepreneur, developing', 'your own software products,or', 'pursuing higher studies. The', 'students are prepa
# ...

# %%
# !pip install langchain-community langchain-huggingface

# %%
! pip install faiss-cpu

# %%
from langchain_community.vectorstores import FAISS
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

embedding_model=HuggingFaceEmbeddings()
db= FAISS.from_texts(
    chunks,
    embedding_model
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
results=db.similarity_search(
    "What is the scope of learning?"
)
print(results[0].page_content)
# Out:
# The scope of learning for you
